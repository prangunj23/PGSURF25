# %%
import pandas as pd

# %%
speeches_df = pd.read_csv('../data/initial_datasets/speeches/speeches_train.csv')
privacy_preserving_df = pd.read_csv('../data/generated/speeches/privacy_preserving_synthetic.csv')

# %%
speeches_df['text'].str.len().mean()
# Out:
# np.float64(20839.93625498008)

# %%
privacy_preserving_df
# Out:
#                                              sentences  labels
# 0    Today, we come together to reaffirm our commit...      -1
# 1    My fellow Americans, we are at a crucial junct...       1
# 2    As Americans, we believe in the power of freed...      -1
# 3    Today, we renew our pledge to advance social j...       1
# 4    Let us stand resolute in our commitment to uph...      -1
# ..                                                 ...     ...
# 914  Ladies and gentlemen, the fundamental principl...      -1
# 915  Education transforms lives and builds stronger...       1
# 916  Our national defense is paramount, and we must...      -1
# 917  In this land of opportunity, we must tackle th...       1
# 918  We must honor the legacy of our founding fathe...      -1
#
# [919 rows x 2 columns]

# %%
privacy_preserving_df['sentences'].str.len().mean()
# Out:
# np.float64(363.1675734494015)
