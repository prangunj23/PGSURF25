# %%
import sys
sys.path.append('../utilities/')
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
import torch
from sentence_transformers import SentenceTransformer
from joblib import dump
from openai import OpenAI
from tqdm import tqdm
from mmd import MMD
import re
from sklearn.feature_extraction.text import CountVectorizer
import random
# Out:
# /Users/pranitgunjal/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
sentence_transformer = SentenceTransformer('all-mpnet-base-v2')

# %% [markdown]
# # **Data Pre-processing**

# %%
train_df = pd.read_csv('../data/initial_datasets/dota2/dota2_train.csv')
test_df = pd.read_csv('../data/initial_datasets/dota2/dota2_test.csv')

# %%
train_df = pd.read_csv('../data/initial_datasets/reddit/reddit_train.csv')
test_df = pd.read_csv('../data/initial_datasets/reddit/reddit_test.csv')

# %%
train_df
# Out:
#                                                 messages  labels
# 0                                        That game hurt.       1
# 1                                     Man I love reddit.       0
# 2      Right? Considering it’s such an important docu...       0
# 3      He isn't as big, but he's still quite popular....       1
# 4      That's crazy; I went to a super [RELIGION] hig...       0
# ...                                                  ...     ...
# 40696  Oh man is this true. Coffee has a seriously ne...       1
# 40697                            You’re good, no worries       0
# 40698  one's a rapist, and the other's a stingy yank ...       1
# 40699  This is great! Can anyone make a request with ...       0
# 40700  This is so cruel. I literally feel physically ...       1
#
# [40701 rows x 2 columns]

# %%
test_df
# Out:
#                                               messages  labels
# 0                                   First is the worst       1
# 1    Our education system has been a complete and u...       1
# 2    The fuck you call me!? A cunt!? Damn man, didn...       1
# 3    It will probably take him some time to figure ...       0
# 4    Somebody is really insecure about their career...       1
# ..                                                 ...     ...
# 995                 Be glad you don't know the answer.       0
# 996  I’m laughing more that I feel I should st this...       0
# 997  I wouldnt necessarily call you and addict but ...       1
# 998  I'm genuinely interested in the responses to t...       0
# 999  I hope things get better soon. I'm proud of yo...       0
#
# [1000 rows x 2 columns]

# %%
df = pd.read_csv('../data/initial_datasets/dota2_train_labels_translated_sanitized.csv')

# %%
df['label'] = df['label'].replace({'x': 1})
df['label'] = df['label'].fillna(0)
df['label'] = df['label'].astype(int)
# Out:
# /var/folders/lv/pnwq6bmj4tq68bsvy__37qyh0000gn/T/ipykernel_91964/2336875256.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['label'] = df['label'].replace({'x': 1})

# %%
test_df = df[['translated_message', 'label']].sample(n=1000)

# %%
train_df = df.drop(test_df.index)

# %%
train_df = train_df[['translated_message', 'label']]

# %%
df['label'].value_counts() / df.shape[0]
# Out:
# label
# 0    0.959815
# 1    0.040185
# Name: count, dtype: float64

# %% [markdown]
# # **Classifier**

# %%
n = [10, 50, 100, 200]

# %%
seeds = [random.randint(0, 2**32 - 1) for _ in range(3)]

# %%
train_df.shape[0]
# Out:
# 2460

# %%
train_df.drop(one_label.index)
# Out:
#                                                messages  labels
# 0                                              "faggot"       0
# 1                                    "there's a monkey"       0
# 2             "Sniper, how do you like our mid player?"       0
# 3                            "You're all corpses, guys"       0
# 4                                             "Not bad"       0
# ...                                                 ...     ...
# 2455  "my Luna hits the one with leggings, now I see...       0
# 2456                                                 GG       0
# 2457            "my shadow doesn't know how to use ult"       0
# 2458                                                 GG       0
# 2459                                  GG REPORT SLARDAR       0
#
# [2459 rows x 2 columns]

# %%
one_label = train_df[train_df['labels'] == 1].sample(n=1, random_state=42)
rest = train_df.drop(one_label.index)

rest_sample = rest.sample(n=9, random_state=42)
train_sample = pd.concat([one_label, rest_sample])
# Out:
#                             messages  labels
# 352      "HERALD ANDERSON IS STUPID"       1
# 757                           ALMOST       0
# 643   "Am I the carry or something?"       0
# 2403                             lol       0
# 1945                            easy       0
# 252                            ":?D"       0
# 354           "LC, duel over there."       0
# 1317                    "I'm a noob"       0
# 1643                             wtf       0
# 237                   "F*CK YEAH!!!"       0

# %%
train_sample['labels'].value_counts()[1]
# Out:
# np.int64(9)

# %%
dota2_seeds = [367402242, 1881848525, 360375685]

# %%
print(seeds)
# Out:
# [367402242, 1881848525, 360375685]

# %%
seeds = [random.randint(0, 2**32 - 1) for _ in range(3)]
for ni in n:
    prec = 0
    recall = 0
    roc_auc = 0
    print(ni)
    for seed in seeds:
        one_label = train_df[train_df['labels'] == 1].sample(n=1, random_state=seed)
        rest = train_df.drop(one_label.index)

        rest_sample = rest.sample(n=(ni-1), random_state=seed)
        train_sample = pd.concat([one_label, rest_sample])
        # print(train_sample['labels'].value_counts()[0])
        # print(train_sample['labels'].value_counts()[1])
        X_train = np.array(sentence_transformer.encode(train_sample['messages'].to_list()))
        y_train = train_sample['labels']

        X_test = np.array(sentence_transformer.encode(test_df['messages'].to_list()))
        y_test = test_df['labels']

        model = svm.SVC(kernel='linear', probability=True, class_weight='balanced')
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        test_acc = accuracy_score(y_test, y_pred)

        # print(ni)
        # print(f"Test Acc: {test_acc}")

        y_prob = model.predict_proba(X_test)[:, 1]
        roc_auc += roc_auc_score(y_test, y_prob)
        prec += precision_score(y_test, y_pred)
        recall += precision_score(y_test, y_pred)
    
    print(f"Roc_Auc: {roc_auc/3}")
    print(f"Precision: {prec/3}")
    print(f"Recall: {recall/3}")
# Out:
# 10
# Roc_Auc: 0.4455947385675653
# Precision: 0.39838951785959686
# Recall: 0.39838951785959686
# 50
# Roc_Auc: 0.43419272544547943
# Precision: 0.5547979027211979
# Recall: 0.5547979027211979
# 100
# Roc_Auc: 0.772140835512951
# Precision: 0.5883436441271567
# Recall: 0.5883436441271567
# 200
# Roc_Auc: 0.7928933726738219
# Precision: 0.6117288904742088
# Recall: 0.6117288904742088

# %%
train_sample = train_df.sample(n=n)

# %%
train_sample['label'].value_counts()
# Out:
# label
# 0    185
# 1     15
# Name: count, dtype: int64

# %%
X_train = np.array(sentence_transformer.encode(train_sample['translated_message'].to_list()))
y_train = train_sample['label']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 X_train = np.array(sentence_transformer.encode(train_sample['translated_message'].to_list()))
#       2 y_train = train_sample['label']
#
# File ~/Library/Python/3.9/lib/python/site-packages/sentence_transformers/SentenceTransformer.py:623, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     620 features.update(extra_features)
#     622 with torch.no_grad():
# --> 623     out_features = self.forward(features, **kwargs)
#     624     if self.device.type == "hpu":
#     625         out_features = copy.deepcopy(out_features)
#
# ...

# %%
X_test = np.array(sentence_transformer.encode(test_df['translated_message'].to_list()))
y_test = test_df['label']

# %%
model = svm.SVC(kernel='linear', probability=True, class_weight='balanced')
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
test_acc = accuracy_score(y_test, y_pred)
print(f"Test Acc: {test_acc}")

print(precision_score(y_test, y_pred))
print(recall_score(y_test, y_pred))

y_prob = model.predict_proba(X_test)[:, 1]
print(roc_auc_score(y_test, y_prob))
# Out:
# Test Acc: 0.933
# 0.21818181818181817
# 0.3333333333333333
# 0.8908050945136007

# %%
roc_auc = 0
prec = 0
recall = 0
seeds = [random.randint(0, 2**32 - 1) for _ in range(3)]
for seed in seeds:
    train_sample = train_df.sample(n=1000, random_state=seed)
    X_train = np.array(sentence_transformer.encode(train_sample['messages'].to_list()))
    y_train = train_sample['labels']

    X_test = np.array(sentence_transformer.encode(test_df['messages'].to_list()))
    y_test = test_df['labels']

    model = svm.SVC(kernel='linear', probability=True, class_weight='balanced')
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, y_pred)

    y_prob = model.predict_proba(X_test)[:, 1]
    roc_auc += roc_auc_score(y_test, y_prob)
    prec += precision_score(y_test, y_pred)
    recall += precision_score(y_test, y_pred)

print(roc_auc / 3)
print(prec / 3)
print(recall / 3)
# Out:
# 0.8263678621994884
# 0.6078898585130313
# 0.6078898585130313
